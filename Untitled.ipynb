# %%
import csv
f = open('C:/Users/MSI/Desktop/training data/participants1.csv')
csv_f = csv.reader(f)
for row in csv_f:
  print (row)
# Out:
# [';;;;;;']
# []
# [';Jackson;Thompson;jackson.thompson@hotmail.com;;;']
# []
# [';Luke;Wallace;luke.wallace@lycos.com;;;']
# []
# [';David;Wright;david.wright@hotmail.com;;;']
# []
# [';Nathaniel;Butler;nathaniel.butler@aol.com;;;']
# []
# [';Noah;Simpson;noah.simpson@hotmail.com;;;']
# []
# [';Eli;Mitchell;eli.mitchell@aol.com;;;']
# []
# [';Xavier;Shaw;xavier.shaw@gmail.com;;;']
# []
# [';Josiah;Harrison;josiah.harrison@aol.com;;;']
# []
# [';Nolan;Thompson;nolan.thompson@aol.com;;;']
# []
# [';Avery;Martin;avery.martin@yahoo.com;;;']
# []
# [';Sydney;Allen;sydney.allen@gmail.com;;;']
# []
# [';Alyssa;Alexander;alyssa.alexander@lycos.com;;;']
# []
# [';Benjamin;Rodriguez;benjamin.rodriguez@aol.com;;;']
# []
# [';Julia;Henry;julia.henry@gmail.com;;;']
# []
# [';Luke;Jordan;luke.jordan@gmail.com;;;']
# []
# [';Henry;Cooper;henry.cooper@aol.com;;;']
# []
# [';Jasmine;Dixon;jasmine.dixon@hotmail.com;;;']
# []
# [';Avery;Brooks;avery.brooks@lycos.com;;;']
# []
# ...

# %%
import csv
f = open('C:/Users/MSI/Desktop/training data/participants2.csv')
csv_f = csv.reader(f)
for row in csv_f:
  print (row)
# Out:
# [';;;;;;']
# []
# [';Jackson;Thompson;jackson.thompson@hotmail.com;;;']
# []
# [';Luke;Wallace;luke.wallace@lycos.com;;;']
# []
# [';Madelyn;Dixon;madelyn.dixon@gmail.com;;;']
# []
# [';Noah;Peterson;noah.peterson@hotmail.com;;;']
# []
# [';David;Wright;david.wright@hotmail.com;;;']
# []
# [';Nathaniel;Butler;nathaniel.butler@aol.com;;;']
# []
# [';Noah;Simpson;noah.simpson@hotmail.com;;;']
# []
# [';Eli;Mitchell;eli.mitchell@aol.com;;;']
# []
# [';Xavier;Shaw;xavier.shaw@gmail.com;;;']
# []
# [';Josiah;Harrison;josiah.harrison@aol.com;;;']
# []
# [';Nolan;Thompson;nolan.thompson@aol.com;;;']
# []
# [';Avery;Martin;avery.martin@yahoo.com;;;']
# []
# [';Sydney;Allen;sydney.allen@gmail.com;;;']
# []
# [';Alyssa;Alexander;alyssa.alexander@lycos.com;;;']
# []
# [';Benjamin;Rodriguez;benjamin.rodriguez@aol.com;;;']
# []
# [';Julia;Henry;julia.henry@gmail.com;;;']
# []
# [';Ryder;Jackson;ryder.jackson@yahoo.com;;;']
# []
# [';Luke;Jordan;luke.jordan@gmail.com;;;']
# []
# ...

# %%
import pandas as pd
df_participants1 = pd.read_csv('C:/Users/MSI/Desktop/training data/participants1.csv',sep=';', header = None,names = ['col1', 'col2', 'col3','col4', 'col5', 'col6','col7'])
df_participants1.head()
# Out:
#    col1       col2      col3                          col4  col5  col6  col7
# 0   NaN        NaN       NaN                           NaN   NaN   NaN   NaN
# 1   NaN    Jackson  Thompson  jackson.thompson@hotmail.com   NaN   NaN   NaN
# 2   NaN       Luke   Wallace        luke.wallace@lycos.com   NaN   NaN   NaN
# 3   NaN      David    Wright      david.wright@hotmail.com   NaN   NaN   NaN
# 4   NaN  Nathaniel    Butler      nathaniel.butler@aol.com   NaN   NaN   NaN

# %%
df_participants1.drop(0,0,inplace=True)
df_participants1.drop(['col1','col5','col6','col7'],1,inplace=True)
df_participants1.head()
# Out:
#         col2      col3                          col4
# 1    Jackson  Thompson  jackson.thompson@hotmail.com
# 2       Luke   Wallace        luke.wallace@lycos.com
# 3      David    Wright      david.wright@hotmail.com
# 4  Nathaniel    Butler      nathaniel.butler@aol.com
# 5       Noah   Simpson      noah.simpson@hotmail.com

# %%
import pandas as pd
df_participants2 = pd.read_csv('C:/Users/MSI/Desktop/training data/participants2.csv',sep=';', header = None,names = ['col1', 'col2', 'col3','col4', 'col5', 'col6','col7'])
df_participants2.head()
# Out:
#    col1     col2      col3                          col4  col5  col6  col7
# 0   NaN      NaN       NaN                           NaN   NaN   NaN   NaN
# 1   NaN  Jackson  Thompson  jackson.thompson@hotmail.com   NaN   NaN   NaN
# 2   NaN     Luke   Wallace        luke.wallace@lycos.com   NaN   NaN   NaN
# 3   NaN  Madelyn     Dixon       madelyn.dixon@gmail.com   NaN   NaN   NaN
# 4   NaN     Noah  Peterson     noah.peterson@hotmail.com   NaN   NaN   NaN

# %%
df_participants2.drop(0,0,inplace=True)
df_participants2.drop(['col1','col5','col6','col7'],1,inplace=True)
df_participants2.head()
# Out:
#       col2      col3                          col4
# 1  Jackson  Thompson  jackson.thompson@hotmail.com
# 2     Luke   Wallace        luke.wallace@lycos.com
# 3  Madelyn     Dixon       madelyn.dixon@gmail.com
# 4     Noah  Peterson     noah.peterson@hotmail.com
# 5    David    Wright      david.wright@hotmail.com

# %%
emails1 = []
emails1 = df_participants1['col4']
emails1.head()
# Out:
# 1    jackson.thompson@hotmail.com
# 2          luke.wallace@lycos.com
# 3        david.wright@hotmail.com
# 4        nathaniel.butler@aol.com
# 5        noah.simpson@hotmail.com
# Name: col4, dtype: object

# %%
emails2 = []
emails2 = df_participants2['col4']
emails2.head()
# Out:
# 1    jackson.thompson@hotmail.com
# 2          luke.wallace@lycos.com
# 3         madelyn.dixon@gmail.com
# 4       noah.peterson@hotmail.com
# 5        david.wright@hotmail.com
# Name: col4, dtype: object

# %%
emails1 = set(emails1)
emails2 = set(emails2)
second_year_participants = emails2.difference(emails1)
print(second_year_participants)
# Out:
# {'ryder.jackson@yahoo.com', 'ava.hawkins@aol.com', 'jasmine.murray@aol.com', 'alyssa.white@aol.com', 'kaylee.perry@gmail.com', 'hunter.simmons@lycos.com', 'noah.mills@gmail.com', 'jasmine.fisher@lycos.com', 'madelyn.dixon@gmail.com', 'zoe.parker@aol.com', 'skylar.thomas@gmail.com', 'noah.peterson@hotmail.com', 'liam.rice@lycos.com', 'lucas.roberts@yahoo.com', 'liam.mills@yahoo.com', 'jordan.knight@gmail.com', 'kayden.stephens@hotmail.com', 'alexander.stone@gmail.com', 'khloe.lopez@aol.com'}
